# %%
import cv2
import numpy as np

# %%
image = cv2.imread("car1.jpg")

# %%
image.shape
# Out:
# (726, 726, 3)

# %%
import matplotlib.pyplot as plt

# %%
img = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.imshow(img)

# %%
img2= cv2.imread("car2.jpg")
img2.shape
# Out:
# (635, 640, 3)

# %%
plt.imshow(img2)

# %%
img3 = img[15:200, 15:260]
img3.shape
# Out:
# (185, 245, 3)

# %%
plt.imshow(img3)

# %%
img4 = cv2.resize(img2, (60,185))

# %%
np.shape(img4)
# Out:
# (185, 60, 3)

# %%
imgfinal = np.hstack((img3,img4))

# %%
plt.imshow(imgfinal)
